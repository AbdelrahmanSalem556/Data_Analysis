# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Data Analysis\Students\Studentdata (1).csv")

# %%
data.describe()
# Out:
#        Unnamed: 0
# count  256.000000
# mean   127.500000
# std     74.045031
# min      0.000000
# 25%     63.750000
# 50%    127.500000
# 75%    191.250000
# max    255.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 25 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                 256 non-null    int64
#  1   2.Gender                                                                                   256 non-null    object
#  2   3. Year of Study                                                                           256 non-null    object
#  3   4. Branch                                                                                  256 non-null    object
#  4   1. Type of Schooling till 10th Grade:                                                      256 non-null    object
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0                                                                                     0
# 2.Gender                                                                                       0
# 3. Year of Study                                                                               0
# 4. Branch                                                                                      0
# 1. Type of Schooling till 10th Grade:                                                          0
# 2. Percentage in Class 10th?                                                                   0
# 3. Location of Class 10th School:                                                              0
# 4. Type of Schooling for class 12th:                                                           0
# 5. Percentage in Class 12th?                                                                   0
# 6. Location of Class 12th School:                                                              0
# ...

# %%
data = data.dropna(subset=['11. Do you have any additional skills?'])
data = data.dropna(subset=['6. Active in developer Communities'])
data = data.dropna(subset=['2.  Actively involved in Specific technology?'])
data = data.dropna(subset=['Achievements:'])

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
data.count()
# Out:
# Unnamed: 0                                                                                   103
# 2.Gender                                                                                     103
# 3. Year of Study                                                                             103
# 4. Branch                                                                                    103
# 1. Type of Schooling till 10th Grade:                                                        103
# 2. Percentage in Class 10th?                                                                 103
# 3. Location of Class 10th School:                                                            103
# 4. Type of Schooling for class 12th:                                                         103
# 5. Percentage in Class 12th?                                                                 103
# 6. Location of Class 12th School:                                                            103
# ...

# %%
data.head()
# Out:
#     Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 0            0     Male            Third    CSE/IT
# 5            5     Male           Second      CSIT
# 9            9     Male           Second        IT
# 11          11   Female           Second       CSE
# 13          13     Male           Second      CSIT
#
#    1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 0                       Normal Schooling               >=80% and <90%
# 5                       Normal Schooling                       >= 90%
# 9                Schooling with Tuitions                       >= 90%
# 11               Schooling with Tuitions                       >= 90%
# 13                      Normal Schooling               >=80% and <90%
#
#    3. Location of Class 10th School: 4. Type of Schooling for class 12th:  \
# 0                               Town                     Normal Schooling
# 5                               Town                     Normal Schooling
# ...

# %%
data.shape
# Out:
# (103, 25)

# %%
sns.countplot(x='2.Gender',data=data)
# Out:
# <Axes: xlabel='2.Gender', ylabel='count'>

# %%
sns.countplot(x='3. Year of Study',data=data)
# Out:
# <Axes: xlabel='3. Year of Study', ylabel='count'>

# %%
sns.countplot(x='4. Type of Schooling for class 12th:',data=data)
# Out:
# <Axes: xlabel='4. Type of Schooling for class 12th:', ylabel='count'>

# %%
# Calculate the frequency of each unique value in the specified column
value_counts = data['6. Location of Class 12th School:'].value_counts()

# Plot a pie chart
plt.figure(figsize=(5, 4)) 
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Values Location of Class 12th School:')
plt.axis('equal')  
plt.show()

# %%
sns.countplot(x='8. Have you made any Software based projects?',data=data)
# Out:
# <Axes: xlabel='8. Have you made any Software based projects?', ylabel='count'>

# %%
sns.countplot(x='9. Have you made any Hardware based project (Arduino, Raspberry Pi, Robots or any other)?',data=data)
# Out:
# <Axes: xlabel='9. Have you made any Hardware based project (Arduino, Raspberry Pi, Robots or any other)?', ylabel='count'>

# %%
sns.countplot(x='10. Have you ever pitched any idea?',data=data)
# Out:
# <Axes: xlabel='10. Have you ever pitched any idea?', ylabel='count'>

# %%
sns.countplot(x='4. Exposure to GitHub ?',data=data)
# Out:
# <Axes: xlabel='4. Exposure to GitHub ?', ylabel='count'>

# %%
data[(data["8. Have you made any Software based projects?"]=='Yes') & (data['9. Have you made any Hardware based project (Arduino, Raspberry Pi, Robots or any other)?']=='Yes')&(data['10. Have you ever pitched any idea?']=='Yes')].duplicated().count()
# Out:
# 11

# %%
data[(data["8. Have you made any Software based projects?"]=='Yes') & (data['9. Have you made any Hardware based project (Arduino, Raspberry Pi, Robots or any other)?']=='Yes')&(data['10. Have you ever pitched any idea?']=='Yes')]
# Out:
#      Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 19           19   Female           Second        IT
# 30           30   Female           Second        CS
# 41           41   Female           Second        CS
# 55           55     Male           Second       ECE
# 60           60     Male           Second       CSE
# 65           65     Male           Second       ECE
# 69           69     Male           Second       ECE
# 101         101     Male            First      CSIT
# 150         150   Female           Second        EN
# 184         184     Male           Second       ECE
# 234         234   Female           Second       ECE
#
#     1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 19                Schooling with Tuitions               >=70% and <80%
# 30                       Normal Schooling               >=80% and <90%
# 41                Schooling with Tuitions                       >= 90%
# ...

# %%
data[(data["2.Gender"]=='Female') | (data['6. Location of Class 12th School:']=='Town')].duplicated().count()
# Out:
# 42

# %%
data[(data["2.Gender"]=='Female') | (data['6. Location of Class 12th School:']=='Town')]
# Out:
#      Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 0             0     Male            Third    CSE/IT
# 5             5     Male           Second      CSIT
# 9             9     Male           Second        IT
# 11           11   Female           Second       CSE
# 17           17   Female           Second       CSE
# 19           19   Female           Second        IT
# 24           24     Male           Second       CSE
# 29           29     Male           Second        CS
# 30           30   Female           Second        CS
# 38           38     Male           Second       CSE
# 39           39     Male           Second      CSIT
# 41           41   Female           Second        CS
# 42           42     Male            Third        CS
# 48           48   Female           Second      CSIT
# 50           50   Female           Second      CSIT
# 52           52     Male           Second        IT
# 69           69     Male           Second       ECE
# ...

# %%
data['11. Do you have any additional skills?'].max
# Out:
# <bound method Series.max of 0                   Cultural Activities
# 5                   Cultural Activities
# 9                    Photography;Sports
# 11                  Cultural Activities
# 13           Sports;Cultural Activities
#                      ...
# 245                Video Editing;Sports
# 248           Photography;Video Editing
# 252                              Sports
# 254    Photography;Video Editing;Sports
# 255                              Sports
# Name: 11. Do you have any additional skills?, Length: 103, dtype: object>

# %%
data[data['11. Do you have any additional skills?'] =='Cultural Activities']['2.Gender'].value_counts()
# Out:
# 2.Gender
# Male      13
# Female    13
# Name: count, dtype: int64

# %%
data[data['11. Do you have any additional skills?'] =='Photography;Video Editing']['2.Gender'].value_counts()
# Out:
# 2.Gender
# Male    2
# Name: count, dtype: int64

# %%
data[(data["2.Gender"]=='Male') & (data['11. Do you have any additional skills?']=='Photography;Video Editing')]
# Out:
#      Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 148         148     Male           Second      CSIT
# 248         248     Male           Second       MCA
#
#     1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 148                      Normal Schooling               >=70% and <80%
# 248                Coaching Based Schools               >=70% and <80%
#
#     3. Location of Class 10th School: 4. Type of Schooling for class 12th:  \
# 148                              City                     Normal Schooling
# 248                              Town               Coaching Based Schools
#
#     5. Percentage in Class 12th? 6. Location of Class 12th School:  ...  \
# 148               >=70% and <80%                              City  ...
# 248               >=60% and <70%                              Town  ...
#
#     3. Exposure to Data structure and algorithms? 4. Exposure to GitHub ?  \
# ...

# %%
data[data['11. Do you have any additional skills?'] =='Photography;Video Editing']['3. Location of Class 10th School:'].value_counts()
# Out:
# 3. Location of Class 10th School:
# City    1
# Town    1
# Name: count, dtype: int64

# %%
data[(data["3. Location of Class 10th School:"]=='City') & (data['11. Do you have any additional skills?']=='Photography;Video Editing')]
# Out:
#      Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 148         148     Male           Second      CSIT
#
#     1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 148                      Normal Schooling               >=70% and <80%
#
#     3. Location of Class 10th School: 4. Type of Schooling for class 12th:  \
# 148                              City                     Normal Schooling
#
#     5. Percentage in Class 12th? 6. Location of Class 12th School:  ...  \
# 148               >=70% and <80%                              City  ...
#
#     3. Exposure to Data structure and algorithms? 4. Exposure to GitHub ?  \
# 148                                        Medium                    Easy
#
#     5. Are you associated with any developer Community?  \
# 148                                                 No
#
#     6. Active in developer Communities  \
# 148                    Inactive Member
#
# ...

# %%
data[(data["3. Location of Class 10th School:"]=='Town') & (data['11. Do you have any additional skills?']=='Photography;Video Editing')]
# Out:
#      Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 248         248     Male           Second       MCA
#
#     1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 248                Coaching Based Schools               >=70% and <80%
#
#     3. Location of Class 10th School: 4. Type of Schooling for class 12th:  \
# 248                              Town               Coaching Based Schools
#
#     5. Percentage in Class 12th? 6. Location of Class 12th School:  ...  \
# 248               >=60% and <70%                              Town  ...
#
#     3. Exposure to Data structure and algorithms? 4. Exposure to GitHub ?  \
# 248                                          Easy                    Easy
#
#     5. Are you associated with any developer Community?  \
# 248                                                 No
#
#     6. Active in developer Communities  \
# 248                    Inactive Member
#
# ...

# %%
data['2. Percentage in Class 10th?'].max
# Out:
# <bound method Series.max of 0      >=80% and <90%
# 5              >= 90%
# 9              >= 90%
# 11             >= 90%
# 13     >=80% and <90%
#             ...
# 245    >=70% and <80%
# 248    >=70% and <80%
# 252    >=80% and <90%
# 254    >=80% and <90%
# 255    >=80% and <90%
# Name: 2. Percentage in Class 10th?, Length: 103, dtype: object>

# %%
data[(data["2.Gender"]=='Male') &( (data['2. Percentage in Class 10th?']=='>=90%') | ( data['5. Percentage in Class 12th?']=='>=90%'))]
# Out:
#      Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 5             5     Male           Second      CSIT
# 9             9     Male           Second        IT
# 14           14     Male           Second       CSE
# 22           22     Male           Second       ECE
# 37           37     Male           Second        IT
# 38           38     Male           Second       CSE
# 39           39     Male           Second      CSIT
# 49           49     Male           Second       CSE
# 52           52     Male           Second        IT
# 56           56     Male           Second      CSIT
# 60           60     Male           Second       CSE
# 65           65     Male           Second       ECE
# 69           69     Male           Second       ECE
# 91           91     Male           Second       CSE
# 92           92     Male           Second       CSE
# 105         105     Male           Second      CSAI
# 106         106     Male            Third       CSE
# ...

# %%
data['5. Percentage in Class 12th?'].mode()[0]   # The most value It was repeated.....
# Out:
# '>=80% and <90%'

# %%
data['5. Percentage in Class 12th?'].value_counts()[:5]  #The 5 most frequent values........
# Out:
# 5. Percentage in Class 12th?
# >=80% and <90%    40
# >=90%             38
# >=70% and <80%    21
# >=60% and <70%     4
# Name: count, dtype: int64

# %%
data[data['1. How many programming languages do you know? '] =='More than 5']['2.Gender']
# Out:
# 0      Male
# 56     Male
# 199    Male
# Name: 2.Gender, dtype: object

# %%
data[data['1. How many programming languages do you know? '] =='More than 5']['2.Gender'].value_counts()
# Out:
# 2.Gender
# Male    3
# Name: count, dtype: int64

# %%
data['4. Branch'].value_counts()[:5]  #The 5 most frequent values........
# Out:
# 4. Branch
# CSIT    25
# CSE     17
# CS      15
# IT      13
# ECE     13
# Name: count, dtype: int64

# %%
data[(data["2.Gender"]=='Male') & (( (data['4. Branch']=='IT'))&(data['3. Year of Study']=='Second'))]
# Out:
#      Unnamed: 0 2.Gender 3. Year of Study 4. Branch  \
# 9             9     Male           Second        IT
# 37           37     Male           Second        IT
# 52           52     Male           Second        IT
# 62           62     Male           Second        IT
# 111         111     Male           Second        IT
# 136         136     Male           Second        IT
# 156         156     Male           Second        IT
# 206         206     Male           Second        IT
# 229         229     Male           Second        IT
#
#     1. Type of Schooling till 10th Grade: 2. Percentage in Class 10th?  \
# 9                 Schooling with Tuitions                       >= 90%
# 37                Schooling with Tuitions                       >= 90%
# 52                       Normal Schooling                       >= 90%
# 62                       Normal Schooling                       >= 90%
# 111                      Normal Schooling               >=70% and <80%
# ...

# %%
data[(data["2.Gender"]=='Male') & (( (data['4. Branch']=='IT'))&(data['3. Year of Study']=='Second'))].duplicated().count()
# Out:
# 9

# %%
sns.countplot(x='6. Active in developer Communities',data=data)
# Out:
# <Axes: xlabel='6. Active in developer Communities', ylabel='count'>

# %%
data['6. Active in developer Communities'].value_counts()
# Out:
# 6. Active in developer Communities
# Moderately active    38
# Active Member        34
# Inactive Member      31
# Name: count, dtype: int64
